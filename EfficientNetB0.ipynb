# %%
from typing import Annotated   #connect to drive folder
from google.colab import drive

drive.mount('/gdrive', force_remount=True)
# %cd /gdrive/My Drive/AN2DL Mattia/HW1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/AN2DL Mattia/HW1

# %%
#IMPORT LIBRARIES

# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from PIL import Image
import matplotlib.gridspec as gridspec
from sklearn.utils.class_weight import compute_class_weight

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %%
#LOAD DATA
data = np.load('Copia di training_set.npz')
X = data['images']
y = data['labels']

# %%
# Define a mapping of labels to their corresponding digit names
labels = {0:'Basophil', 1:'Eosinophil', 2:'Erythroblast', 3:'Immature granulocytes', 4:'Lymphocyt', 5:'Monocyte', 6:'Neutrophil', 7:'Platelet'}

# Save unique labels
unique_labels = list(labels.values())

# Display a sample of images from the dataset
num_img = 25
random_indices = random.sample(range(len(X)), num_img)
fig, axes = plt.subplots(5, 5, figsize=(20, 20))

# Iterate through the selected number of images
for i, idx in enumerate(random_indices):
    row, col = divmod(i, 5)
    ax = axes[row, col]
    ax.imshow(np.squeeze(X[idx]), vmin=0., vmax=1.)
    ax.set_title(f'{labels[y[idx][0]]} idx: {idx}')
    ax.axis('off')

# Adjust layout and display the images
plt.tight_layout()
plt.show()

# Inspect the target
print('Counting occurrences of target classes:')
print(pd.DataFrame(y, columns=['digit'])['digit'].value_counts())
# Out:
# Counting occurrences of target classes:
# digit
# 6    2530
# 1    2381
# 3    2226
# 7    1843
# 5    1393
# 2    1285
# 0    1052
# 4    1049
# Name: count, dtype: int64

# %%
# Identify and delete images with Shrek background
Shrek_index= 13515
immagine_ripetuta = X[Shrek_index]

# Find all indices of images
indici_da_rimuovere = []
for i in range(len(X)):
    if np.array_equal(X[i], immagine_ripetuta):
        indici_da_rimuovere.append(i)

# Remove the images
X= np.delete(X, indici_da_rimuovere, axis=0)
y= np.delete(y, indici_da_rimuovere, axis=0)

# %%
# Identify and delete images with Meme background
Meme_index= 11998
immagine_ripetuta = X[Meme_index]

# Find all indices of images
indici_da_rimuovere = []
for i in range(len(X)):
    if np.array_equal(X[i], immagine_ripetuta):
        indici_da_rimuovere.append(i)

# Remove the images
X= np.delete(X, indici_da_rimuovere, axis=0)
y= np.delete(y, indici_da_rimuovere, axis=0)

# %%
# Display a sample of images from the dataset to see if it has been cleaned
num_img = 64
random_indices = random.sample(range(len(X)), num_img)
fig, axes = plt.subplots(8, 8, figsize=(20, 20))

# Iterate through the selected number of images
for i, idx in enumerate(random_indices):
    row, col = divmod(i, 8)
    ax = axes[row, col]
    ax.imshow(np.squeeze(X[idx]), vmin=0., vmax=1.)
    ax.set_title(f'{labels[y[idx][0]]} idx: {idx}')
    ax.axis('off')

# Adjust layout and display the images
plt.tight_layout()
plt.show()

# Inspect the target
print('Counting occurrences of target classes:')
print(pd.DataFrame(y, columns=['digit'])['digit'].value_counts())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Normalize data to the range [0, 1]
X = (X / 255).astype('float32')

#Dividing the test set from train+val
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=0.1, stratify=y)

#Splitting training and validation
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=0.1, stratify=y_train_val)



# Convert labels to categorical format using one-hot encoding
y_train_val = tfk.utils.to_categorical(y_train_val)
y_test = tfk.utils.to_categorical(y_test)

y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)


print("Training and validation Data Shape:", X_train_val.shape)
print("Training and validation Label Shape:", y_train_val.shape)
print("Test Data Shape:", X_test.shape)
print("Test Label Shape:", y_test.shape)
# Out:
# Training and validation Data Shape: (10763, 96, 96, 3)
# Training and validation Label Shape: (10763, 8)
# Test Data Shape: (1196, 96, 96, 3)
# Test Label Shape: (1196, 8)

# %%
import numpy as np
from collections import Counter

# Converte y_train da one-hot encoded a etichette numeriche
y_train_labels = np.argmax(y_train, axis=1)

# Conta le occorrenze di ciascuna classe nel dataset di training
class_counts = Counter(y_train_labels)

# Determina la soglia per definire le classi minoritarie
# Ad esempio, puoi considerare una classe minoritaria se ha meno del 50% della media delle occorrenze
threshold = 0.8 * np.mean(list(class_counts.values()))

# Identifica le classi minoritarie in base alla soglia
minority_classes = [label for label, count in class_counts.items() if count < threshold]
#minority_classes.append(3)  hand insert class 3 as minority since was the most misclassified

print("Classi minoritarie:", minority_classes)
print("Distribuzione delle classi nel dataset di training:", class_counts)
# Out:
# Classi minoritarie: [2, 4, 0, 5, 3]
# Distribuzione delle classi nel dataset di training: Counter({6: 1887, 1: 1767, 3: 1641, 7: 1331, 2: 878, 5: 804, 0: 690, 4: 688})

# %%
# Define a sequential model for image augmentation with various geometrical transformations
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.1,0.1),
    tfkl.RandomRotation(0.2),
], name='Augmentation')

def augment_minority_class(images):
    # Applica augmentation a una lista di immagini di classi minoritarie
    augmented_images = [augmentation(img) for img in images]
    return augmented_images

# Applica augmentation per le classi minoritarie
for class_label in minority_classes:
    # Ottieni tutte le immagini della classe minoritaria
    y_train_labels = np.argmax(y_train, axis=1)
    minority_images = X_train[y_train_labels == class_label]

    # Genera immagini augmentate per questa classe
    augmented_images = augment_minority_class(minority_images)

    # Aggiungi le immagini aumentate al dataset di training
    X_train = np.concatenate((X_train, augmented_images), axis=0)

    # Genera etichette in formato one-hot per le immagini aumentate
    augmented_labels = tf.keras.utils.to_categorical([class_label] * len(augmented_images), num_classes=y_train.shape[1])

    # Aggiungi le etichette one-hot al dataset di training
    y_train = np.concatenate((y_train, augmented_labels), axis=0)

# %%
# Inspect the target
print('Counting occurrences of target classes:')
y_train_labels = np.argmax(y_train, axis=1)
print(pd.DataFrame(y_train_labels, columns=['digit'])['digit'].value_counts())
# Out:
# Counting occurrences of target classes:
# digit
# 3    3282
# 6    1887
# 1    1767
# 2    1756
# 5    1608
# 0    1380
# 4    1376
# 7    1331
# Name: count, dtype: int64

# %%
# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]

print("Input Shape:", input_shape)
print("Output Shape:", output_shape)

#################################################
# Number of training epochs
epochs = 300

# Batch size for training
batch_size = 128

# Learning rate: step size for updating the model's weights
learning_rate = 0.0001

# Print the defined parameters
print("Epochs:", epochs)
print("Batch Size:", batch_size)
print("Learning Rate:", learning_rate)
# Out:
# Input Shape: (96, 96, 3)
# Output Shape: 8
# Epochs: 300
# Batch Size: 128
# Learning Rate: 0.0001

# %%
# Initialise EfficientNetB0 model with pretrained weights, for transfer learning
efficientnet = tfk.applications.EfficientNetB0(
    input_shape=(96, 96, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Freeze all layers in EfficientNetB0 to use it solely as a feature extractor
efficientnet.trainable = False

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

#augmentation for training set
augmentation2 = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal_and_vertical"),
    tfkl.RandomTranslation(0.1,0.1),
    tfkl.RandomRotation(0.2),
    tfkl.RandomContrast(0.5)
], name='Augmentation')

x = augmentation2(inputs)

# Pass augmented inputs through the EfficientNetB0 feature extractor
x = efficientnet(x)

# Reshape l'output per garantire che abbia 4 dimensioni (batch_size, height, width, channels)
# EfficientNetB0 normalmente ha output con (None, 3, 3, 1280), puoi usare questa forma o adattarla in base alle necessità
x = tfkl.Reshape((-1, 1, 1280))(x)

# Add a Global Average Pooling layer explicitly
x = tfkl.GlobalAveragePooling2D(name='gap')(x)

# Adding two more layers with Dropout
x = tfkl.Dense(512, activation = 'relu', name='dense_512')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.3)(x)
x = tfkl.Dense(512, activation=tfkl.LeakyReLU(alpha=0.2), name='dense_256')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.2)(x)

# Add final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', name='dense')(x)

# Define the complete model linking input and output
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model with categorical cross-entropy loss and AdamW optimizer
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(),optimizer=tfk.optimizers.AdamW(learning_rate=5e-5), metrics=['accuracy'])

# %%
# Train the model
tl_history = tl_model.fit(
    x=X_train * 255,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val * 255, y_val),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
               tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file
model_filename = 'Mattia0512.keras'
tl_model.save(model_filename)

# Plot training and validation loss
plt.figure(figsize=(15, 2))
plt.plot(tl_history['loss'], label='Training loss', alpha=.8)
plt.plot(tl_history['val_loss'], label='Validation loss', alpha=.8)
plt.title('TL_Loss')
plt.legend()
plt.grid(alpha=.3)

# Plot training and validation accuracy
plt.figure(figsize=(15, 2))
plt.plot(tl_history['accuracy'], label='Training accuracy', alpha=.8)
plt.plot(tl_history['val_accuracy'], label='Validation accuracy', alpha=.8)
plt.title('TL_Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()
# Out:
# Epoch 1/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 27s 115ms/step - accuracy: 0.1703 - loss: 2.1003 - val_accuracy: 0.2823 - val_loss: 1.8955 - learning_rate: 5.0000e-05
# Epoch 2/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.3439 - loss: 1.8160 - val_accuracy: 0.3946 - val_loss: 1.6645 - learning_rate: 5.0000e-05
# Epoch 3/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.4499 - loss: 1.6266 - val_accuracy: 0.4875 - val_loss: 1.4967 - learning_rate: 5.0000e-05
# Epoch 4/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.5358 - loss: 1.4832 - val_accuracy: 0.5422 - val_loss: 1.3718 - learning_rate: 5.0000e-05
# Epoch 5/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.5927 - loss: 1.3707 - val_accuracy: 0.5840 - val_loss: 1.2715 - learning_rate: 5.0000e-05
# Epoch 6/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6270 - loss: 1.2784 - val_accuracy: 0.6165 - val_loss: 1.1890 - learning_rate: 5.0000e-05
# Epoch 7/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.6460 - loss: 1.2033 - val_accuracy: 0.6416 - val_loss: 1.1225 - learning_rate: 5.0000e-05
# Epoch 8/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.6550 - loss: 1.1502 - val_accuracy: 0.6685 - val_loss: 1.0668 - learning_rate: 5.0000e-05
# Epoch 9/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6619 - loss: 1.1096 - val_accuracy: 0.6750 - val_loss: 1.0228 - learning_rate: 5.0000e-05
# Epoch 10/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.6850 - loss: 1.0573 - val_accuracy: 0.6871 - val_loss: 0.9777 - learning_rate: 5.0000e-05
# Epoch 11/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.6861 - loss: 1.0280 - val_accuracy: 0.6936 - val_loss: 0.9427 - learning_rate: 5.0000e-05
# Epoch 12/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.6979 - loss: 0.9990 - val_accuracy: 0.7075 - val_loss: 0.9113 - learning_rate: 5.0000e-05
# Epoch 13/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.7155 - loss: 0.9476 - val_accuracy: 0.7149 - val_loss: 0.8845 - learning_rate: 5.0000e-05
# Epoch 14/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7228 - loss: 0.9259 - val_accuracy: 0.7196 - val_loss: 0.8614 - learning_rate: 5.0000e-05
# Epoch 15/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7204 - loss: 0.9048 - val_accuracy: 0.7326 - val_loss: 0.8406 - learning_rate: 5.0000e-05
# Epoch 16/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7180 - loss: 0.8997 - val_accuracy: 0.7419 - val_loss: 0.8199 - learning_rate: 5.0000e-05
# Epoch 17/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7223 - loss: 0.8835 - val_accuracy: 0.7456 - val_loss: 0.8038 - learning_rate: 5.0000e-05
# Epoch 18/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7359 - loss: 0.8427 - val_accuracy: 0.7502 - val_loss: 0.7834 - learning_rate: 5.0000e-05
# Epoch 19/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.7402 - loss: 0.8292 - val_accuracy: 0.7530 - val_loss: 0.7653 - learning_rate: 5.0000e-05
# Epoch 20/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7438 - loss: 0.8183 - val_accuracy: 0.7567 - val_loss: 0.7530 - learning_rate: 5.0000e-05
# Epoch 21/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.7486 - loss: 0.8113 - val_accuracy: 0.7604 - val_loss: 0.7432 - learning_rate: 5.0000e-05
# Epoch 22/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7443 - loss: 0.8051 - val_accuracy: 0.7604 - val_loss: 0.7337 - learning_rate: 5.0000e-05
# Epoch 23/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7591 - loss: 0.7707 - val_accuracy: 0.7651 - val_loss: 0.7199 - learning_rate: 5.0000e-05
# Epoch 24/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.7573 - loss: 0.7613 - val_accuracy: 0.7697 - val_loss: 0.7093 - learning_rate: 5.0000e-05
# Epoch 25/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.7546 - loss: 0.7640 - val_accuracy: 0.7734 - val_loss: 0.6987 - learning_rate: 5.0000e-05
# Epoch 26/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.7602 - loss: 0.7565 - val_accuracy: 0.7772 - val_loss: 0.6881 - learning_rate: 5.0000e-05
# Epoch 27/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.7612 - loss: 0.7392 - val_accuracy: 0.7790 - val_loss: 0.6789 - learning_rate: 5.0000e-05
# Epoch 28/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7679 - loss: 0.7218 - val_accuracy: 0.7818 - val_loss: 0.6675 - learning_rate: 5.0000e-05
# Epoch 29/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.7676 - loss: 0.7175 - val_accuracy: 0.7855 - val_loss: 0.6618 - learning_rate: 5.0000e-05
# Epoch 30/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7781 - loss: 0.6974 - val_accuracy: 0.7902 - val_loss: 0.6525 - learning_rate: 5.0000e-05
# Epoch 31/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7727 - loss: 0.7013 - val_accuracy: 0.7948 - val_loss: 0.6468 - learning_rate: 5.0000e-05
# Epoch 32/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7765 - loss: 0.6934 - val_accuracy: 0.7929 - val_loss: 0.6393 - learning_rate: 5.0000e-05
# Epoch 33/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7770 - loss: 0.6866 - val_accuracy: 0.7929 - val_loss: 0.6333 - learning_rate: 5.0000e-05
# Epoch 34/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.7872 - loss: 0.6742 - val_accuracy: 0.7976 - val_loss: 0.6248 - learning_rate: 5.0000e-05
# Epoch 35/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.7901 - loss: 0.6550 - val_accuracy: 0.8004 - val_loss: 0.6179 - learning_rate: 5.0000e-05
# Epoch 36/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.7889 - loss: 0.6519 - val_accuracy: 0.7994 - val_loss: 0.6133 - learning_rate: 5.0000e-05
# Epoch 37/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7896 - loss: 0.6458 - val_accuracy: 0.8041 - val_loss: 0.6082 - learning_rate: 5.0000e-05
# Epoch 38/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.7951 - loss: 0.6439 - val_accuracy: 0.8059 - val_loss: 0.6026 - learning_rate: 5.0000e-05
# Epoch 39/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.7912 - loss: 0.6444 - val_accuracy: 0.8059 - val_loss: 0.5978 - learning_rate: 5.0000e-05
# Epoch 40/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7942 - loss: 0.6359 - val_accuracy: 0.8078 - val_loss: 0.5938 - learning_rate: 5.0000e-05
# Epoch 41/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7942 - loss: 0.6346 - val_accuracy: 0.8078 - val_loss: 0.5888 - learning_rate: 5.0000e-05
# Epoch 42/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7977 - loss: 0.6264 - val_accuracy: 0.8143 - val_loss: 0.5813 - learning_rate: 5.0000e-05
# Epoch 43/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8044 - loss: 0.6140 - val_accuracy: 0.8143 - val_loss: 0.5748 - learning_rate: 5.0000e-05
# Epoch 44/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8055 - loss: 0.6119 - val_accuracy: 0.8143 - val_loss: 0.5737 - learning_rate: 5.0000e-05
# Epoch 45/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8042 - loss: 0.5977 - val_accuracy: 0.8171 - val_loss: 0.5706 - learning_rate: 5.0000e-05
# Epoch 46/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8061 - loss: 0.5915 - val_accuracy: 0.8152 - val_loss: 0.5621 - learning_rate: 5.0000e-05
# Epoch 47/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8046 - loss: 0.6081 - val_accuracy: 0.8162 - val_loss: 0.5616 - learning_rate: 5.0000e-05
# Epoch 48/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.8108 - loss: 0.5992 - val_accuracy: 0.8152 - val_loss: 0.5552 - learning_rate: 5.0000e-05
# Epoch 49/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8092 - loss: 0.5856 - val_accuracy: 0.8208 - val_loss: 0.5515 - learning_rate: 5.0000e-05
# Epoch 50/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8097 - loss: 0.5807 - val_accuracy: 0.8227 - val_loss: 0.5500 - learning_rate: 5.0000e-05
# Epoch 51/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8047 - loss: 0.5915 - val_accuracy: 0.8217 - val_loss: 0.5480 - learning_rate: 5.0000e-05
# Epoch 52/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.8196 - loss: 0.5733 - val_accuracy: 0.8245 - val_loss: 0.5423 - learning_rate: 5.0000e-05
# Epoch 53/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8117 - loss: 0.5672 - val_accuracy: 0.8208 - val_loss: 0.5402 - learning_rate: 5.0000e-05
# Epoch 54/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8107 - loss: 0.5802 - val_accuracy: 0.8254 - val_loss: 0.5339 - learning_rate: 5.0000e-05
# Epoch 55/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8170 - loss: 0.5639 - val_accuracy: 0.8236 - val_loss: 0.5354 - learning_rate: 5.0000e-05
# Epoch 56/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8155 - loss: 0.5620 - val_accuracy: 0.8273 - val_loss: 0.5286 - learning_rate: 5.0000e-05
# Epoch 57/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8152 - loss: 0.5611 - val_accuracy: 0.8273 - val_loss: 0.5277 - learning_rate: 5.0000e-05
# Epoch 58/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.8135 - loss: 0.5699 - val_accuracy: 0.8273 - val_loss: 0.5254 - learning_rate: 5.0000e-05
# Epoch 59/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.8158 - loss: 0.5667 - val_accuracy: 0.8273 - val_loss: 0.5212 - learning_rate: 5.0000e-05
# Epoch 60/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8127 - loss: 0.5660 - val_accuracy: 0.8282 - val_loss: 0.5177 - learning_rate: 5.0000e-05
# Epoch 61/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8185 - loss: 0.5653 - val_accuracy: 0.8282 - val_loss: 0.5144 - learning_rate: 5.0000e-05
# Epoch 62/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8226 - loss: 0.5482 - val_accuracy: 0.8273 - val_loss: 0.5145 - learning_rate: 5.0000e-05
# Epoch 63/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8210 - loss: 0.5468 - val_accuracy: 0.8292 - val_loss: 0.5103 - learning_rate: 5.0000e-05
# Epoch 64/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8257 - loss: 0.5355 - val_accuracy: 0.8301 - val_loss: 0.5053 - learning_rate: 5.0000e-05
# Epoch 65/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8236 - loss: 0.5384 - val_accuracy: 0.8301 - val_loss: 0.5052 - learning_rate: 5.0000e-05
# Epoch 66/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8239 - loss: 0.5383 - val_accuracy: 0.8310 - val_loss: 0.5032 - learning_rate: 5.0000e-05
# Epoch 67/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8263 - loss: 0.5335 - val_accuracy: 0.8319 - val_loss: 0.4990 - learning_rate: 5.0000e-05
# Epoch 68/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8227 - loss: 0.5366 - val_accuracy: 0.8319 - val_loss: 0.4980 - learning_rate: 5.0000e-05
# Epoch 69/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8226 - loss: 0.5392 - val_accuracy: 0.8338 - val_loss: 0.4983 - learning_rate: 5.0000e-05
# Epoch 70/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8187 - loss: 0.5386 - val_accuracy: 0.8319 - val_loss: 0.4955 - learning_rate: 5.0000e-05
# Epoch 71/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8338 - loss: 0.5186 - val_accuracy: 0.8329 - val_loss: 0.4902 - learning_rate: 5.0000e-05
# Epoch 72/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8302 - loss: 0.5281 - val_accuracy: 0.8329 - val_loss: 0.4890 - learning_rate: 5.0000e-05
# Epoch 73/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8327 - loss: 0.5183 - val_accuracy: 0.8347 - val_loss: 0.4871 - learning_rate: 5.0000e-05
# Epoch 74/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8326 - loss: 0.5123 - val_accuracy: 0.8329 - val_loss: 0.4860 - learning_rate: 5.0000e-05
# Epoch 75/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.8294 - loss: 0.5175 - val_accuracy: 0.8357 - val_loss: 0.4850 - learning_rate: 5.0000e-05
# Epoch 76/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8304 - loss: 0.5116 - val_accuracy: 0.8357 - val_loss: 0.4856 - learning_rate: 5.0000e-05
# Epoch 77/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8316 - loss: 0.5134 - val_accuracy: 0.8375 - val_loss: 0.4787 - learning_rate: 5.0000e-05
# Epoch 78/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.8302 - loss: 0.5136 - val_accuracy: 0.8384 - val_loss: 0.4772 - learning_rate: 5.0000e-05
# Epoch 79/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8323 - loss: 0.5114 - val_accuracy: 0.8366 - val_loss: 0.4811 - learning_rate: 5.0000e-05
# Epoch 80/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8381 - loss: 0.4999 - val_accuracy: 0.8375 - val_loss: 0.4785 - learning_rate: 5.0000e-05
# Epoch 81/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8354 - loss: 0.5113 - val_accuracy: 0.8366 - val_loss: 0.4769 - learning_rate: 5.0000e-05
# Epoch 82/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8382 - loss: 0.5074 - val_accuracy: 0.8366 - val_loss: 0.4713 - learning_rate: 5.0000e-05
# Epoch 83/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8388 - loss: 0.4908 - val_accuracy: 0.8366 - val_loss: 0.4740 - learning_rate: 5.0000e-05
# Epoch 84/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8388 - loss: 0.4876 - val_accuracy: 0.8384 - val_loss: 0.4688 - learning_rate: 5.0000e-05
# Epoch 85/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8372 - loss: 0.4932 - val_accuracy: 0.8384 - val_loss: 0.4689 - learning_rate: 5.0000e-05
# Epoch 86/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8386 - loss: 0.4927 - val_accuracy: 0.8412 - val_loss: 0.4664 - learning_rate: 5.0000e-05
# Epoch 87/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.8389 - loss: 0.4983 - val_accuracy: 0.8412 - val_loss: 0.4666 - learning_rate: 5.0000e-05
# Epoch 88/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.8476 - loss: 0.4737 - val_accuracy: 0.8412 - val_loss: 0.4617 - learning_rate: 5.0000e-05
# Epoch 89/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.8434 - loss: 0.4864 - val_accuracy: 0.8403 - val_loss: 0.4609 - learning_rate: 5.0000e-05
# Epoch 90/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8414 - loss: 0.4849 - val_accuracy: 0.8422 - val_loss: 0.4605 - learning_rate: 5.0000e-05
# Epoch 91/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8442 - loss: 0.4825 - val_accuracy: 0.8477 - val_loss: 0.4565 - learning_rate: 5.0000e-05
# Epoch 92/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8421 - loss: 0.4796 - val_accuracy: 0.8468 - val_loss: 0.4568 - learning_rate: 5.0000e-05
# Epoch 93/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8384 - loss: 0.4930 - val_accuracy: 0.8477 - val_loss: 0.4568 - learning_rate: 5.0000e-05
# Epoch 94/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8410 - loss: 0.4834 - val_accuracy: 0.8449 - val_loss: 0.4549 - learning_rate: 5.0000e-05
# Epoch 95/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.8445 - loss: 0.4724 - val_accuracy: 0.8487 - val_loss: 0.4535 - learning_rate: 5.0000e-05
# Epoch 96/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8424 - loss: 0.4841 - val_accuracy: 0.8514 - val_loss: 0.4552 - learning_rate: 5.0000e-05
# Epoch 97/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8419 - loss: 0.4683 - val_accuracy: 0.8524 - val_loss: 0.4512 - learning_rate: 5.0000e-05
# Epoch 98/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8449 - loss: 0.4671 - val_accuracy: 0.8533 - val_loss: 0.4470 - learning_rate: 5.0000e-05
# Epoch 99/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8451 - loss: 0.4748 - val_accuracy: 0.8542 - val_loss: 0.4480 - learning_rate: 5.0000e-05
# Epoch 100/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8412 - loss: 0.4711 - val_accuracy: 0.8542 - val_loss: 0.4477 - learning_rate: 5.0000e-05
# Epoch 101/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.8488 - loss: 0.4659 - val_accuracy: 0.8542 - val_loss: 0.4469 - learning_rate: 5.0000e-05
# Epoch 102/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.8436 - loss: 0.4707 - val_accuracy: 0.8542 - val_loss: 0.4467 - learning_rate: 5.0000e-05
# Epoch 103/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8464 - loss: 0.4783 - val_accuracy: 0.8533 - val_loss: 0.4441 - learning_rate: 5.0000e-05
# Epoch 104/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8429 - loss: 0.4727 - val_accuracy: 0.8524 - val_loss: 0.4442 - learning_rate: 5.0000e-05
# Epoch 105/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8505 - loss: 0.4560 - val_accuracy: 0.8533 - val_loss: 0.4406 - learning_rate: 5.0000e-05
# Epoch 106/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8475 - loss: 0.4670 - val_accuracy: 0.8542 - val_loss: 0.4414 - learning_rate: 5.0000e-05
# Epoch 107/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8458 - loss: 0.4630 - val_accuracy: 0.8552 - val_loss: 0.4402 - learning_rate: 5.0000e-05
# Epoch 108/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8496 - loss: 0.4621 - val_accuracy: 0.8561 - val_loss: 0.4369 - learning_rate: 5.0000e-05
# Epoch 109/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8446 - loss: 0.4697 - val_accuracy: 0.8552 - val_loss: 0.4369 - learning_rate: 5.0000e-05
# Epoch 110/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8448 - loss: 0.4644 - val_accuracy: 0.8542 - val_loss: 0.4378 - learning_rate: 5.0000e-05
# Epoch 111/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8531 - loss: 0.4562 - val_accuracy: 0.8542 - val_loss: 0.4356 - learning_rate: 5.0000e-05
# Epoch 112/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.8486 - loss: 0.4614 - val_accuracy: 0.8570 - val_loss: 0.4329 - learning_rate: 5.0000e-05
# Epoch 113/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8532 - loss: 0.4588 - val_accuracy: 0.8552 - val_loss: 0.4346 - learning_rate: 5.0000e-05
# Epoch 114/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8495 - loss: 0.4483 - val_accuracy: 0.8561 - val_loss: 0.4327 - learning_rate: 5.0000e-05
# Epoch 115/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.8487 - loss: 0.4632 - val_accuracy: 0.8561 - val_loss: 0.4299 - learning_rate: 5.0000e-05
# Epoch 116/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8492 - loss: 0.4555 - val_accuracy: 0.8561 - val_loss: 0.4298 - learning_rate: 5.0000e-05
# Epoch 117/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8549 - loss: 0.4443 - val_accuracy: 0.8552 - val_loss: 0.4311 - learning_rate: 5.0000e-05
# Epoch 118/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8502 - loss: 0.4462 - val_accuracy: 0.8561 - val_loss: 0.4301 - learning_rate: 5.0000e-05
# Epoch 119/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8493 - loss: 0.4502 - val_accuracy: 0.8552 - val_loss: 0.4287 - learning_rate: 5.0000e-05
# Epoch 120/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8506 - loss: 0.4537 - val_accuracy: 0.8570 - val_loss: 0.4272 - learning_rate: 5.0000e-05
# Epoch 121/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.8477 - loss: 0.4536 - val_accuracy: 0.8561 - val_loss: 0.4297 - learning_rate: 5.0000e-05
# Epoch 122/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.8492 - loss: 0.4485 - val_accuracy: 0.8561 - val_loss: 0.4238 - learning_rate: 5.0000e-05
# Epoch 123/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8465 - loss: 0.4511 - val_accuracy: 0.8542 - val_loss: 0.4278 - learning_rate: 5.0000e-05
# Epoch 124/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8560 - loss: 0.4456 - val_accuracy: 0.8542 - val_loss: 0.4243 - learning_rate: 5.0000e-05
# Epoch 125/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8502 - loss: 0.4381 - val_accuracy: 0.8561 - val_loss: 0.4216 - learning_rate: 5.0000e-05
# Epoch 126/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8508 - loss: 0.4471 - val_accuracy: 0.8579 - val_loss: 0.4223 - learning_rate: 5.0000e-05
# Epoch 127/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.8431 - loss: 0.4668 - val_accuracy: 0.8570 - val_loss: 0.4206 - learning_rate: 5.0000e-05
# Epoch 128/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.8513 - loss: 0.4489 - val_accuracy: 0.8570 - val_loss: 0.4199 - learning_rate: 5.0000e-05
# Epoch 129/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8573 - loss: 0.4393 - val_accuracy: 0.8598 - val_loss: 0.4195 - learning_rate: 5.0000e-05
# Epoch 130/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8588 - loss: 0.4330 - val_accuracy: 0.8589 - val_loss: 0.4186 - learning_rate: 5.0000e-05
# Epoch 131/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8536 - loss: 0.4435 - val_accuracy: 0.8570 - val_loss: 0.4182 - learning_rate: 5.0000e-05
# Epoch 132/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8584 - loss: 0.4323 - val_accuracy: 0.8552 - val_loss: 0.4173 - learning_rate: 5.0000e-05
# Epoch 133/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8579 - loss: 0.4256 - val_accuracy: 0.8579 - val_loss: 0.4147 - learning_rate: 5.0000e-05
# Epoch 134/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8585 - loss: 0.4304 - val_accuracy: 0.8570 - val_loss: 0.4176 - learning_rate: 5.0000e-05
# Epoch 135/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8574 - loss: 0.4263 - val_accuracy: 0.8570 - val_loss: 0.4186 - learning_rate: 5.0000e-05
# Epoch 136/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8609 - loss: 0.4291 - val_accuracy: 0.8552 - val_loss: 0.4145 - learning_rate: 5.0000e-05
# Epoch 137/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.8565 - loss: 0.4288 - val_accuracy: 0.8552 - val_loss: 0.4145 - learning_rate: 5.0000e-05
# Epoch 138/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8525 - loss: 0.4441 - val_accuracy: 0.8561 - val_loss: 0.4148 - learning_rate: 5.0000e-05
# Epoch 139/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8525 - loss: 0.4434 - val_accuracy: 0.8570 - val_loss: 0.4099 - learning_rate: 5.0000e-05
# Epoch 140/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8574 - loss: 0.4235 - val_accuracy: 0.8579 - val_loss: 0.4111 - learning_rate: 5.0000e-05
# Epoch 141/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8512 - loss: 0.4392 - val_accuracy: 0.8579 - val_loss: 0.4121 - learning_rate: 5.0000e-05
# Epoch 142/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8582 - loss: 0.4343 - val_accuracy: 0.8607 - val_loss: 0.4090 - learning_rate: 5.0000e-05
# Epoch 143/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8540 - loss: 0.4376 - val_accuracy: 0.8570 - val_loss: 0.4087 - learning_rate: 5.0000e-05
# Epoch 144/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8617 - loss: 0.4218 - val_accuracy: 0.8570 - val_loss: 0.4082 - learning_rate: 5.0000e-05
# Epoch 145/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8679 - loss: 0.4108 - val_accuracy: 0.8589 - val_loss: 0.4062 - learning_rate: 5.0000e-05
# Epoch 146/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.8585 - loss: 0.4237 - val_accuracy: 0.8589 - val_loss: 0.4057 - learning_rate: 5.0000e-05
# Epoch 147/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8599 - loss: 0.4244 - val_accuracy: 0.8589 - val_loss: 0.4057 - learning_rate: 5.0000e-05
# Epoch 148/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.8658 - loss: 0.4144 - val_accuracy: 0.8589 - val_loss: 0.4025 - learning_rate: 5.0000e-05
# Epoch 149/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8583 - loss: 0.4187 - val_accuracy: 0.8589 - val_loss: 0.4054 - learning_rate: 5.0000e-05
# Epoch 150/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.8671 - loss: 0.4105 - val_accuracy: 0.8626 - val_loss: 0.4047 - learning_rate: 5.0000e-05
# Epoch 151/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8589 - loss: 0.4274 - val_accuracy: 0.8598 - val_loss: 0.4058 - learning_rate: 5.0000e-05
# Epoch 152/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8607 - loss: 0.4211 - val_accuracy: 0.8617 - val_loss: 0.4037 - learning_rate: 5.0000e-05
# Epoch 153/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.8565 - loss: 0.4331 - val_accuracy: 0.8579 - val_loss: 0.4060 - learning_rate: 5.0000e-05
# Epoch 154/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8626 - loss: 0.4157 - val_accuracy: 0.8598 - val_loss: 0.4027 - learning_rate: 2.5000e-05
# Epoch 155/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8586 - loss: 0.4237 - val_accuracy: 0.8617 - val_loss: 0.4022 - learning_rate: 2.5000e-05
# Epoch 156/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8608 - loss: 0.4235 - val_accuracy: 0.8579 - val_loss: 0.4038 - learning_rate: 2.5000e-05
# Epoch 157/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8642 - loss: 0.4108 - val_accuracy: 0.8598 - val_loss: 0.4029 - learning_rate: 2.5000e-05
# Epoch 158/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8632 - loss: 0.4179 - val_accuracy: 0.8598 - val_loss: 0.4032 - learning_rate: 2.5000e-05
# Epoch 159/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8615 - loss: 0.4148 - val_accuracy: 0.8579 - val_loss: 0.4031 - learning_rate: 2.5000e-05
# Epoch 160/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8593 - loss: 0.4151 - val_accuracy: 0.8598 - val_loss: 0.4007 - learning_rate: 2.5000e-05
# Epoch 161/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - accuracy: 0.8614 - loss: 0.4280 - val_accuracy: 0.8589 - val_loss: 0.4013 - learning_rate: 2.5000e-05
# Epoch 162/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.8630 - loss: 0.4193 - val_accuracy: 0.8607 - val_loss: 0.4009 - learning_rate: 2.5000e-05
# Epoch 163/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.8606 - loss: 0.4113 - val_accuracy: 0.8589 - val_loss: 0.4009 - learning_rate: 2.5000e-05
# Epoch 164/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.8540 - loss: 0.4185 - val_accuracy: 0.8598 - val_loss: 0.4015 - learning_rate: 2.5000e-05
# Epoch 165/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8630 - loss: 0.4168 - val_accuracy: 0.8607 - val_loss: 0.4011 - learning_rate: 2.5000e-05
# Epoch 166/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.8588 - loss: 0.4256 - val_accuracy: 0.8607 - val_loss: 0.4008 - learning_rate: 1.2500e-05
# Epoch 167/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.8608 - loss: 0.4206 - val_accuracy: 0.8607 - val_loss: 0.4008 - learning_rate: 1.2500e-05
# Epoch 168/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.8604 - loss: 0.4188 - val_accuracy: 0.8607 - val_loss: 0.3995 - learning_rate: 1.2500e-05
# Epoch 169/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8601 - loss: 0.4180 - val_accuracy: 0.8589 - val_loss: 0.3991 - learning_rate: 1.2500e-05
# Epoch 170/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8539 - loss: 0.4267 - val_accuracy: 0.8598 - val_loss: 0.3989 - learning_rate: 1.2500e-05
# Final validation accuracy: 86.26%

# %%
# Calcola la Test Loss e la Test Accuracy
tl_test_loss, tl_test_accuracy = tl_model.evaluate(X_test * 255, y_test,
                                             batch_size=batch_size, verbose=0)

# Converti l'accuratezza in percentuale
tl_test_accuracy *= 100

# Stampa i risultati
print('TL Test loss:', tl_test_loss)
print('TL Test accuracy (%):', tl_test_accuracy)
# Out:
# TL Test loss: 0.35726654529571533
# TL Test accuracy (%): 88.46153616905212

# %%
# Re-load the model after transfer learning
ft_model = tfk.models.load_model('Mattia0512.keras')

# Imposta il modello base come trainabile (EfficientNetB4)
ft_model.get_layer('efficientnetb0').trainable = True

# Congela tutti i layer eccetto gli ultimi 10
for i, layer in enumerate(ft_model.get_layer('efficientnetb0').layers):
    if i < len(ft_model.get_layer('efficientnetb0').layers) - 10:  # Congela i primi layer
        layer.trainable = False
    else:  # Scongela gli ultimi 10 layer
        layer.trainable = True

# Congela sempre i layer di batch normalization (buona prassi)
for layer in ft_model.get_layer('efficientnetb0').layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False

# Compile the model with categorical cross-entropy loss and Adam optimizer
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(learning_rate=1e-5), metrics=['accuracy'])

# Esegui il fine-tuning del modello
ft_history = ft_model.fit(
    x=X_train * 255,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val * 255, y_val),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True)]
).history

# Calcola e stampa l'accuratezza finale sulla validation
final_val_accuracy = round(max(ft_history['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Calcola la Test Loss e la Test Accuracy
ft_test_loss, ft_test_accuracy = ft_model.evaluate(X_test * 255, y_test,
                                             batch_size=batch_size, verbose=0)

# Converti l'accuratezza in percentuale
ft_test_accuracy *= 100

# Stampa i risultati
print('FT Test loss:', ft_test_loss)
print('FT Test accuracy (%):', ft_test_accuracy)

# Salva il modello con il valore di accuratezza incluso nel nome del file
model_filename = 'Tia.keras'
ft_model.save(model_filename)
# Out:
# Epoch 1/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.8266 - loss: 0.4910 - val_accuracy: 0.8403 - val_loss: 0.4577
# Epoch 2/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.8431 - loss: 0.4409 - val_accuracy: 0.8542 - val_loss: 0.4256
# Epoch 3/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8570 - loss: 0.4073 - val_accuracy: 0.8561 - val_loss: 0.4030
# Epoch 4/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8630 - loss: 0.3870 - val_accuracy: 0.8644 - val_loss: 0.3860
# Epoch 5/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.8656 - loss: 0.3843 - val_accuracy: 0.8691 - val_loss: 0.3730
# Epoch 6/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.8772 - loss: 0.3510 - val_accuracy: 0.8784 - val_loss: 0.3523
# Epoch 7/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8734 - loss: 0.3570 - val_accuracy: 0.8793 - val_loss: 0.3450
# Epoch 8/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8796 - loss: 0.3454 - val_accuracy: 0.8774 - val_loss: 0.3406
# Epoch 9/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.8812 - loss: 0.3411 - val_accuracy: 0.8867 - val_loss: 0.3299
# Epoch 10/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8794 - loss: 0.3408 - val_accuracy: 0.8867 - val_loss: 0.3234
# Epoch 11/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8829 - loss: 0.3317 - val_accuracy: 0.8867 - val_loss: 0.3167
# Epoch 12/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8880 - loss: 0.3161 - val_accuracy: 0.8904 - val_loss: 0.3068
# Epoch 13/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8865 - loss: 0.3096 - val_accuracy: 0.8904 - val_loss: 0.3060
# Epoch 14/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.8870 - loss: 0.3166 - val_accuracy: 0.8849 - val_loss: 0.3037
# Epoch 15/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8956 - loss: 0.3015 - val_accuracy: 0.8923 - val_loss: 0.2927
# Epoch 16/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8911 - loss: 0.3102 - val_accuracy: 0.8942 - val_loss: 0.2863
# Epoch 17/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8945 - loss: 0.3007 - val_accuracy: 0.8979 - val_loss: 0.2899
# Epoch 18/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8975 - loss: 0.2956 - val_accuracy: 0.8960 - val_loss: 0.2774
# Epoch 19/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.8955 - loss: 0.2954 - val_accuracy: 0.8979 - val_loss: 0.2756
# Epoch 20/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8990 - loss: 0.2879 - val_accuracy: 0.9016 - val_loss: 0.2709
# Epoch 21/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0
300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.9391 - loss: 0.1707 - val_accuracy: 0.9378 - val_loss: 0.1737
# Epoch 147/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.9414 - loss: 0.1677 - val_accuracy: 0.9350 - val_loss: 0.1680
# Epoch 148/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.9370 - loss: 0.1783 - val_accuracy: 0.9369 - val_loss: 0.1691
# Final validation accuracy: 94.06%
# FT Test loss: 0.15901784598827362
# FT Test accuracy (%): 94.73243951797485

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy')
ax2.set_ylim([min(tl_history['val_accuracy']) * 0.95, max(ft_history['val_accuracy']) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %%
# Predict labels for the entire test set
predictions = ft_model.predict(X_test*255, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)*100
print(f'Accuracy score over the test set: {round(accuracy, 2)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(labels.values()), yticklabels=list(labels.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (1196, 8)
# Accuracy score over the test set: 94.73
# Precision score over the test set: 0.9477

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.

        The following is an example loading the weights of a pre-trained
        model.
        """
        self.neural_network = tfk.models.load_model('Tia.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must no be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Overwriting model.py

# %%
from datetime import datetime
filename = f'submission_{datetime.now().strftime("%y%m%d_%H%M%S")}.zip'

# Add files to the zip command if needed
# !zip {filename} model.py Tia.keras

from google.colab import files
files.download(filename)
# Out:
#   adding: model.py (deflated 56%)
#   adding: Tia.keras (deflated 10%)
